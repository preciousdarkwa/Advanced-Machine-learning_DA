# %% [markdown]
# ## Business Understanding

# %% [markdown]
# The dataset is about Adidas sales and was downloaded from Kaggle. It includes details such as the number of units sold, total sales, sales location, product type, and other relevant information. Tools used include Pandas, NumPy, Matplotlib, Seaborn, Scikit-learn.

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# This data analysis and visualization project aims to provide Adidas with valuable insights into its sales data, including:
#
# - The top-selling Adidas products and categories
# - The most popular Adidas retailers
# - Sales trends over time
#
# These insights will help Adidas to make informed decisions about its product development, marketing, and retail strategies.
#
# The project will use a variety of data analysis and visualization techniques, including:
#
# - Data cleaning and preprocessing
# - Exploratory data analysis (EDA) to identify patterns and trends in the data
# - Data visualization to communicate the findings of the analysis in a clear and concise way

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# The project’s objectives encompass: Sales performance evaluation, purchase rates, product analysis, pricing and profit analysis and sales method evaluation.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# The Adidas Sales dataset includes the following columns:
#
# - Retailer: Represents the name of the retailer involved in the sales transaction.
# - Retailer_ID: A numeric identifier assigned to each retailer for tracking and identification purposes.
# - Invoice_Date: The date when the sales transaction took place.
# - Region: Denotes the broader geographical region where the sales activity occurred.
# - State: Specifies the state or province associated with the sales transaction.
# - City: Indicates the city where the sales took place.
# - Product: Describes the name or identifier of the product being sold.
# - Price_per_Unit: Represents the unit price of the product sold.
# - Units_Sold: Signifies the quantity of units sold for a particular product in a single transaction.
# - Total_Sales: The total monetary value generated by the sales transaction, calculated by multiplying the price per unit and units sold.
# - Operating_Profit: Refers to the profit earned from the sales transaction.
# - Sales_Method: Indicates the method or channel through which the sales transaction was conducted, such as online, in-store, or through a third-party platform.

# %%
# Import librabries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load the Dataset
adidas_sales = pd.read_csv("Dataset_Python_Project.csv")

# %% [markdown]
# ## Data Inspection

# %%
adidas_sales.head(10)
# Out:
#         Retailer  Retailer ID Invoice Date     Region        State  \
# 0        Walmart      1128299    6/17/2021  Southeast      Florida
# 1      West Gear      1128299    7/16/2021      South    Louisiana
# 2  Sports Direct      1197831    8/25/2021      South      Alabama
# 3  Sports Direct      1197831    8/27/2021      South      Alabama
# 4  Sports Direct      1197831    8/21/2021      South      Alabama
# 5      West Gear      1185732    1/11/2021    Midwest     Missouri
# 6  Sports Direct      1185732   11/17/2021      South  Mississippi
# 7  Sports Direct      1197831    1/23/2021      South  Mississippi
# 8      West Gear      1185732     4/3/2021    Midwest    Wisconsin
# 9    Foot Locker      1185732    3/10/2020  Northeast     New York
#
#           City                  Product  Price per Unit  Units Sold  \
# 0      Orlando          Women's Apparel           103.0         218
# 1  New Orleans          Women's Apparel           103.0         163
# ...

# %%
adidas_sales.tail(5)
# Out:
#            Retailer  Retailer ID Invoice Date     Region        State  \
# 9632         Amazon      1185732   11/18/2021  Northeast        Maine
# 9633         Amazon      1185732   10/22/2021       West       Alaska
# 9634         Amazon      1185732   10/22/2021       West       Alaska
# 9635      West Gear      1185732    4/10/2021    Midwest      Indiana
# 9636  Sports Direct      1185732    10/5/2021  Northeast  Connecticut
#
#               City                    Product  Price per Unit  Units Sold  \
# 9632      Portland              Men's Apparel            65.0         150
# 9633     Anchorage  Women's Athletic Footwear            65.0         150
# 9634     Anchorage              Men's Apparel            75.0         150
# 9635  Indianapolis              Men's Apparel            65.0         150
# 9636      Hartford              Men's Apparel            65.0         150
#
#       Total Sales  Operating Profit Sales Method
# 9632         9750              2438       Outlet
# ...

# %%
#Checking the shape of the dataset
adidas_sales.shape
# Out:
# (9637, 12)

# %%
#Columns of the dataset
adidas_sales.columns
# Out:
# Index(['Retailer', 'Retailer ID', 'Invoice Date', 'Region', 'State', 'City',
#        'Product', 'Price per Unit', 'Units Sold', 'Total Sales',
#        'Operating Profit', 'Sales Method'],
#       dtype='object')

# %%
#Brief info on the dataset
adidas_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9637 entries, 0 to 9636
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Retailer          9637 non-null   object
#  1   Retailer ID       9637 non-null   int64
#  2   Invoice Date      9637 non-null   object
#  3   Region            9637 non-null   object
#  4   State             9637 non-null   object
#  5   City              9637 non-null   object
#  6   Product           9637 non-null   object
#  7   Price per Unit    9635 non-null   float64
#  8   Units Sold        9637 non-null   int64
#  9   Total Sales       9637 non-null   int64
#  10  Operating Profit  9637 non-null   int64
#  11  Sales Method      9637 non-null   object
# dtypes: float64(1), int64(4), object(7)
# memory usage: 903.6+ KB

# %%
#Summary Statistics on the dataset
adidas_sales.describe()
# Out:
#         Retailer ID  Price per Unit   Units Sold   Total Sales  \
# count  9.637000e+03     9635.000000  9637.000000   9637.000000
# mean   1.173846e+06       45.217955   256.886064   9320.334855
# std    2.636304e+04       14.705179   214.097600  14184.590862
# min    1.128299e+06        7.000000     6.000000     16.000000
# 25%    1.185732e+06       35.000000   106.000000    426.000000
# 50%    1.185732e+06       45.000000   176.000000    958.000000
# 75%    1.185732e+06       55.000000   350.000000  15000.000000
# max    1.197831e+06      110.000000  1275.000000  82500.000000
#
#        Operating Profit
# count       9637.000000
# mean        3440.706029
# std         5418.210200
# min            8.000000
# 25%          192.000000
# 50%          437.000000
# 75%         5200.000000
# max        39000.000000

# %% [markdown]
# ## Data Cleaning

# %%
#Renaming columns
adidas_sales.rename(columns={"Retail": "Retailer_ID",
            "Invoice Date": "Invoice_Date",
            "Price per Unit": "Price_per_Unit",
            "Units Sold": "Units_Sold",
            "Total Sales": "Total_Sales",
            "Operating Profit": "Profit",
            "Sales Method": "Sales_Method"}, inplace=True)

# %%
adidas_sales.head(5)
# Out:
#         Retailer  Retailer ID Invoice_Date     Region      State         City  \
# 0        Walmart      1128299   2021-06-17  Southeast    Florida      Orlando
# 1      West Gear      1128299   2021-07-16      South  Louisiana  New Orleans
# 2  Sports Direct      1197831   2021-08-25      South    Alabama   Birmingham
# 3  Sports Direct      1197831   2021-08-27      South    Alabama   Birmingham
# 4  Sports Direct      1197831   2021-08-21      South    Alabama   Birmingham
#
#                    Product  Price_per_Unit  Units_Sold  Total_Sales  Profit  \
# 0          Women's Apparel           103.0         218         2245    1257
# 1          Women's Apparel           103.0         163         1679     806
# 2    Men's Street Footwear            10.0         700         7000    3150
# 3  Women's Street Footwear            15.0         575         8625    3881
# 4  Women's Street Footwear            15.0         475         7125    3206
#
#   Sales_Method  Year  Month  Season
# ...

# %% [markdown]
# ### Changing DataTypes

# %%
adidas_sales.dtypes
# Out:
# Retailer          category
# Retailer ID          int64
# Invoice_Date        object
# Region            category
# State               object
# City                object
# Product           category
# Price_per_Unit     float64
# Units_Sold           int64
# Total_Sales          int64
# Profit               int64
# Sales_Method        object
# dtype: object

# %%
adidas_sales['Retailer']= adidas_sales['Retailer'].astype('category')
adidas_sales['Region']= adidas_sales['Region'].astype('category')
adidas_sales['Product']= adidas_sales['Product'].astype('category')
adidas_sales['Sales_Method']= adidas_sales['Sales_Method'].astype('category')
adidas_sales['Price_per_Unit'] = adidas_sales['Price_per_Unit'].astype(float)
adidas_sales['Units_Sold'] = adidas_sales['Units_Sold'].astype(int)
adidas_sales['Profit'] = adidas_sales['Profit'].astype(int)
adidas_sales['Invoice_Date'] = pd.to_datetime(adidas_sales['Invoice_Date'])

# %%
adidas_sales.dtypes
# Out:
# Retailer                category
# Retailer ID                int64
# Invoice_Date      datetime64[ns]
# Region                  category
# State                     object
# City                      object
# Product                 category
# Price_per_Unit           float64
# Units_Sold                 int32
# Total_Sales                int64
# Profit                     int32
# Sales_Method            category
# dtype: object

# %% [markdown]
# ### Finding Null Values

# %%
null_values = adidas_sales.isnull().sum()
null_values
# Out:
# Retailer          0
# Retailer ID       0
# Invoice_Date      0
# Region            0
# State             0
# City              0
# Product           0
# Price_per_Unit    2
# Units_Sold        0
# Total_Sales       0
# Profit            0
# Sales_Method      0
# dtype: int64

# %%
###Replace null values in 'Price_per_Unit'
adidas_sales.loc[adidas_sales['Price_per_Unit'].isnull(), 'Price_per_Unit'] = (
    adidas_sales['Total_Sales']/adidas_sales['Units_Sold'])

### Checking for existing null values
adidas_sales['Price_per_Unit'].isnull().sum()
# Out:
# 0

# %%
adidas_sales.shape
# Out:
# (9637, 12)

# %% [markdown]
# ### Working on Duplicates

# %%
#Check for number of  duplicate entries
adidas_sales.duplicated().sum()
# Out:
# 0

# %%
### Split the date column into year and month columns
adidas_sales['Year'] = adidas_sales['Invoice_Date'].dt.year
adidas_sales['Month'] = adidas_sales['Invoice_Date'].dt.month
                                   
adidas_sales.head(5)
# Out:
#         Retailer  Retailer ID Invoice_Date     Region      State         City  \
# 0        Walmart      1128299   2021-06-17  Southeast    Florida      Orlando
# 1      West Gear      1128299   2021-07-16      South  Louisiana  New Orleans
# 2  Sports Direct      1197831   2021-08-25      South    Alabama   Birmingham
# 3  Sports Direct      1197831   2021-08-27      South    Alabama   Birmingham
# 4  Sports Direct      1197831   2021-08-21      South    Alabama   Birmingham
#
#                    Product  Price_per_Unit  Units_Sold  Total_Sales  Profit  \
# 0          Women's Apparel           103.0         218         2245    1257
# 1          Women's Apparel           103.0         163         1679     806
# 2    Men's Street Footwear            10.0         700         7000    3150
# 3  Women's Street Footwear            15.0         575         8625    3881
# 4  Women's Street Footwear            15.0         475         7125    3206
#
#   Sales_Method  Year  Month
# ...

# %%
### Set 'Season' column
adidas_sales['Season'] = adidas_sales['Invoice_Date'].dt.month.map({3: 'Spring', 4: 'Spring', 5: 'Spring',
                                                6: 'Summer', 7: 'Summer', 8: 'Summer',
                                                9: 'Autumn', 10: 'Autumn', 11: 'Autumn',
                                                12: 'Winter', 1: 'Winter', 2: 'Winter'})

adidas_sales
# Out:
#            Retailer  Retailer ID Invoice_Date     Region        State  \
# 0           Walmart      1128299   2021-06-17  Southeast      Florida
# 1         West Gear      1128299   2021-07-16      South    Louisiana
# 2     Sports Direct      1197831   2021-08-25      South      Alabama
# 3     Sports Direct      1197831   2021-08-27      South      Alabama
# 4     Sports Direct      1197831   2021-08-21      South      Alabama
# ...             ...          ...          ...        ...          ...
# 9632         Amazon      1185732   2021-11-18  Northeast        Maine
# 9633         Amazon      1185732   2021-10-22       West       Alaska
# 9634         Amazon      1185732   2021-10-22       West       Alaska
# 9635      West Gear      1185732   2021-04-10    Midwest      Indiana
# 9636  Sports Direct      1185732   2021-10-05  Northeast  Connecticut
#
#               City                    Product  Price_per_Unit  Units_Sold  \
# ...

# %% [markdown]
# ## Sales Analysis

# %% [markdown]
# ### 1. Sales Performance by Retailer

# %%
# Group the data by the retailers and sum total sales
grouped_data = adidas_sales.groupby('Retailer')['Total_Sales'].sum()

# Bar plot
plt.figure(figsize=(10, 5))
bar_plot = plt.bar(grouped_data.index, grouped_data.values)

# Add data labels
for bar in bar_plot:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height):,}', ha='center', va='bottom', color='black')

# Remove y-axis
plt.gca().yaxis.set_visible(False)

# Set the title and labels
plt.xlabel('Retailer')
plt.ylabel('Total Sales')
plt.title('Sales Performance by Retailer')

# Rotating the x-axis labels for better readability (optional)
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# Find the retailer with the highest sales
max_retailer = grouped_data.idxmax()
print(f"The retailer with the highest sales is: '{max_retailer}'")
# Out:
# The retailer with the highest sales is: 'West Gear'

# %% [markdown]
# ### 2. Sales Distribution by Product Category

# %%
# Grouping the data by product category and calculate the total sales for each category
category_sales = adidas_sales.groupby('Product')['Total_Sales'].sum()

# Pie chart
plt.figure(figsize=(10,5))
plt.pie(category_sales.values, labels=category_sales.index, autopct='%1.1f%%', shadow=True)

plt.title('Sales Distribution by Product Category')

plt.show()

# %% [markdown]
# ### 3. Seasonal Sales Analysis

# %%
# Group by 'Season' and sum 'Total Sales'
season_sales = adidas_sales.groupby('Season')['Total_Sales'].sum().reset_index()

# Create bar chart with adjusted figure size using Seaborn
plt.figure(figsize=(8, 6))  # Adjust the figure size as needed
bar_plot = sns.barplot(x='Season', y='Total_Sales', data=season_sales, palette='tab20b')

# Add data labels
for bar in bar_plot.patches:
    height = bar.get_height()
    bar_plot.text(bar.get_x() + bar.get_width() / 2, height, f'${int(height):,}', ha='center', va='bottom', color='white')

# Remove y-axis
plt.gca().yaxis.set_visible(False)

# Set the title and labels
plt.title('Seasonal Sales')
plt.xlabel('Season')
plt.ylabel('Total Sales')

# Save the plot as an image
plt.savefig('seasonal_sales.png')

# Display the plot
plt.show()

# Find the season with the highest sales
max_season = season_sales.loc[season_sales['Total_Sales'].idxmax(), 'Season']
print(f"The highest sales occurred in the Season: '{max_season}'")
# Out:
# The highest sales occurred in the Season: 'Summer'

# %% [markdown]
# ### 4. Top 5 States by Sales

# %%
# Grouping data and selecting top 5 states by total sales
grouped_data = adidas_sales.groupby('State')['Total_Sales'].sum().reset_index().nlargest(5, 'Total_Sales')

# Barplot
plt.figure(figsize=(10, 5))
bar_plot = sns.barplot(data=grouped_data, x='State', y='Total_Sales')

# Add data labels
for bar in bar_plot.patches:
    height = bar.get_height()
    bar_plot.text(bar.get_x() + bar.get_width() / 2, height, f'${int(height):,}', ha='center', va='bottom', color='black')

# Remove y-axis
plt.gca().yaxis.set_visible(False)

# Set the title and labels
plt.xlabel('States')
plt.ylabel('Total Sales')
plt.title('Top 5 States by Sales')

plt.show()

# %% [markdown]
# ### 6. Sales Trend

# %%
# Filter data for 2020 and 2021
adidas_sales_2020 = adidas_sales[adidas_sales['Year'] == 2020]
adidas_sales_2021 = adidas_sales[adidas_sales['Year'] == 2021]

# Group by month and sum 'Total Sales' for each year
sales_2020 = adidas_sales_2020.groupby('Month')['Total_Sales'].sum()
sales_2021 = adidas_sales_2021.groupby('Month')['Total_Sales'].sum()

# Plot trend chart
plt.figure(figsize=(10, 2.5))
plt.plot(sales_2020.index, sales_2020.values, label='2020', marker='+')
plt.plot(sales_2021.index, sales_2021.values, label='2021', marker='o')
plt.title('Total Sales Trend Comparison (2020 vs 2021)')
plt.xlabel('Month')
plt.ylabel('Total Sales')
plt.xticks(range(1, 13), ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])
plt.legend()
plt.grid(False)

# Save the plot as an image
plt.savefig('sales_trend.png')

plt.show()

# %% [markdown]
# ### Distribution of Price_per_Unit

# %%
# Extracting the price per unit data
price_per_unit_data = adidas_sales['Price_per_Unit']

# Histogram
plt.figure(figsize=(10, 5))
sns.histplot(price_per_unit_data, bins=10, kde=True)

# Add the mean price line
mean_price_per_unit = price_per_unit_data.mean()
plt.axvline(mean_price_per_unit, color='black', linestyle='dashed', linewidth=2, label=f'Mean Price: ${mean_price_per_unit:,.2f}')
plt.legend()

plt.xlabel('Price per Unit')
plt.ylabel('Frequency')
plt.title('Histogram of Price per Unit')

plt.show()

# %% [markdown]
# ### Find Unique Categories and Generating Insights

# %%
#Unique values of Regions
adidas_sales.Region.unique()
# Out:
# ['Southeast', 'South', 'Midwest', 'Northeast', 'West']
# Categories (5, object): ['Midwest', 'Northeast', 'South', 'Southeast', 'West']

# %%
### Count the occurrences of each Region
region_count = adidas_sales["Region"].value_counts()

### Convert series to DataFrame
region_count_adidas_sales = region_count.reset_index()

### Rename columns
region_count_adidas_sales.columns = ['Region', 'Count']

### Display the DataFrame
region_count_adidas_sales
# Out:
#       Region  Count
# 0       West   2446
# 1  Northeast   2376
# 2    Midwest   1865
# 3      South   1726
# 4  Southeast   1224

# %% [markdown]
# ## Purchase Analysis

# %% [markdown]
# ### 1. Regional Purchases

# %%
# Count the occurrences of each product
product_count = adidas_sales['Retailer'].value_counts().reset_index()
product_count.columns = ['Retailer', 'Count']

# Sort values by count
product_count = product_count.sort_values(by='Count', ascending=False)

# Create vertical bar chart with Seaborn
plt.figure(figsize=(10, 4))
bar_plot = sns.barplot(x='Retailer', y='Count', data=product_count, palette='colorblind')

# Add data labels
for bar in bar_plot.patches:
    height = bar.get_height()
    bar_plot.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height):,}', ha='center', va='bottom', color='black')

# Hide y-axis ticks and labels
plt.gca().axes.get_yaxis().set_visible(False)  # Hide the y-axis labels

# Set the title and labels
plt.title("Purchase Count by Retailer")
plt.xlabel("Retailer")
plt.ylabel("")

# Save the plot as an image
plt.savefig('retailer_count.png')

# Display the plot
plt.show()

# %% [markdown]
# ### 2. Regional Purchases

# %%
### Count the occurrences of each product
region_count = adidas_sales['Region'].value_counts()

plt.figure(figsize=(10, 6))
bar_plot = region_count.plot(kind='bar')

### Add data labels
# Add data labels
for bar in bar_plot.patches:
    height = bar.get_height()
    bar_plot.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height):,}', ha='center', va='bottom', color='black')

# Hide y-axis ticks and labels
plt.gca().axes.get_yaxis().set_visible(False)

# Set y-axis label
plt.ylabel('Count', labelpad=10, rotation=0, ha='right')

# Visualizing Product Count
plt.title("Purchase Count by Region")
plt.xlabel('Region')
plt.xticks(rotation=45)

# Save the plot as an image
plt.savefig('region_count.png')

plt.show()

# %%
#Unique values of Sales_Method
adidas_sales.Sales_Method.unique()
# Out:
# ['Online', 'Outlet', 'In-store']
# Categories (3, object): ['In-store', 'Online', 'Outlet']

# %%
### Count the occurrences of each Sales_Method
salesm_count = adidas_sales["Sales_Method"].value_counts()

### Convert series to DataFrame
salesm_count_adidas_sales = salesm_count.reset_index()

### Rename columns
salesm_count_adidas_sales.columns = ['Sales_Method', 'Count']

### Display the DataFrame
salesm_count_adidas_sales
# Out:
#   Sales_Method  Count
# 0       Online   4887
# 1       Outlet   3010
# 2     In-store   1740

# %% [markdown]
# ## Sales Method Evaluation

# %%
#Visualizing Sles methods represented in data
sales_method_count = adidas_sales['Sales_Method'].value_counts()
sales_method_count.plot(kind='pie', autopct='%1.1f%%', startangle=140)
plt.title('Distribution of Sales Methods')
plt.ylabel('')

# Save the plot as an image
plt.savefig('sales_method_distribution.png')

plt.show()

# %%
#Unique values of Products
adidas_sales.Product.unique()
# Out:
# ['Women's Apparel', 'Men's Street Footwear', 'Women's Street Footwear', 'Men's Athletic Footwear', 'Women's Athletic Footwear', 'Men's Apparel', 'Men's aparel']
# Categories (7, object): ['Men's Apparel', 'Men's Athletic Footwear', 'Men's Street Footwear', 'Men's aparel', 'Women's Apparel', 'Women's Athletic Footwear', 'Women's Street Footwear']

# %%
### Count of Products
adidas_sales["Product"].value_counts()
# Out:
# Product
# Men's Street Footwear        1610
# Men's Athletic Footwear      1608
# Women's Apparel              1607
# Women's Street Footwear      1606
# Men's Apparel                1604
# Women's Athletic Footwear    1601
# Men's aparel                    1
# Name: count, dtype: int64

# %%
### Replace Men's aparel with Men's Apparel
adidas_sales['Product'] = adidas_sales['Product'].replace("Men's aparel", "Men's Apparel")

# %%
### Count the occurrences of each product
product_count = adidas_sales["Product"].value_counts()

### Convert series to DataFrame
product_count_adidas_sales = product_count.reset_index()

### Rename columns
product_count_adidas_sales.columns = ['Product', 'Count']

### Display the DataFrame
product_count_adidas_sales
# Out:
#                      Product  Count
# 0      Men's Street Footwear   1610
# 1    Men's Athletic Footwear   1608
# 2            Women's Apparel   1607
# 3    Women's Street Footwear   1606
# 4              Men's Apparel   1605
# 5  Women's Athletic Footwear   1601

# %% [markdown]
# ## Profit Analysis

# %% [markdown]
# ### Profit per Retailer

# %%
# Grouping the data by retailer and calculate the total operating profit
operating_profit_by_retailer = adidas_sales.groupby('Retailer')['Profit'].sum()

# Bar plot
plt.figure(figsize=(10, 5))
bar_plot = plt.bar(operating_profit_by_retailer.index, operating_profit_by_retailer)

# Add data labels
for bar in bar_plot:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{int(height):,}', ha='center', va='bottom', color='black')

# Hide y-axis ticks and labels
plt.gca().axes.get_yaxis().set_visible(False)

# Set the title and labels
plt.xlabel('Retailer')
plt.ylabel('Profit')
plt.title('Profit by Retailer')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Graphical Representation of Product Growth Rate

# %%
# Separate sales data by year
adidas_sales_2020 = adidas_sales[adidas_sales['Year'] == 2020]
adidas_sales_2021 = adidas_sales[adidas_sales['Year'] == 2021]

# Group by Retailer and sum 'Total_Sales' for each year
sales_2020 = adidas_sales_2020.groupby('Product')['Total_Sales'].sum().reset_index()
sales_2021 = adidas_sales_2021.groupby('Product')['Total_Sales'].sum().reset_index()

# Rename columns for merging
sales_2020.columns = ['Product', 'sales_2020']
sales_2021.columns = ['Product', 'sales_2021']

# Merge sales data for 2020 and 2021
merged_sales = pd.merge(sales_2020, sales_2021, on='Product')

# Calculate the growth rate
merged_sales['Growth_Rate'] = (merged_sales['sales_2021'] - merged_sales['sales_2020']) / merged_sales['sales_2020'] * 100

# Sort values by growth rate
merged_sales = merged_sales.sort_values(by='Growth_Rate', ascending=False)

# Create horizontal bar chart with Seaborn using 'tab10' palette
plt.figure(figsize=(10, 5))
bar_plot = sns.barplot(x='Growth_Rate', y='Product', data=merged_sales, palette='tab10')

for bar in bar_plot.patches:
    width = bar.get_width()
    bar_plot.text(width, bar.get_y() + bar.get_height() / 2, f'{width:.2f}%', ha='center', va='center', color='black')

# Hide x-axis label
plt.gca().axes.get_xaxis().set_visible(True)  # Keep the y-axis visible for retailer names

# Set the title and labels
plt.title("Growth Rate by Product")
plt.xlabel("Growth Rate (%)")
plt.ylabel("")

# Save the plot as an image
plt.savefig('growth_rate.png')

# Display the plot
plt.show()

# %% [markdown]
# ### Conclusion

# %% [markdown]
# After doing my analysis I came up with a few observations about the Adidas Sales. Below are some of the observations.
#
# - West Gear is the best-performing Retailer in terms of Total Sales and Profitability.
# - Foot Locker is the best-performing Retailer in terms of purchase counts.
# - New York is the State with the highest sales.
# - West Region has the highest number of purchases.
# - Men's Street Footwear has the highest number of sales.
# - Online Sales is the most preferable sales method.

# %% [markdown]
# ## MACHINE LEARNING

# %% [markdown]
# ### 1. Linear Regression Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor 
from sklearn.metrics import r2_score

# %%
adidas_sales.head(10)
# Out:
#    Retailer  Retailer ID Invoice_Date     Region  State         City  Product  \
# 0         4      1128299   2021-06-17  Southeast      8      Orlando        3
# 1         5      1128299   2021-07-16      South     17  New Orleans        3
# 2         3      1197831   2021-08-25      South      0   Birmingham        2
# 3         3      1197831   2021-08-27      South      0   Birmingham        5
# 4         3      1197831   2021-08-21      South      0   Birmingham        5
# 5         5      1185732   2021-01-11    Midwest     24    St. Louis        5
# 6         3      1185732   2021-11-17      South     23      Jackson        1
# 7         3      1197831   2021-01-23      South     23      Jackson        5
# 8         5      1185732   2021-04-03    Midwest     48    Milwaukee        2
# 9         1      1185732   2020-03-10  Northeast     31     New York        2
#
#    Price_per_Unit  Units_Sold  Total_Sales  Profit Sales_Method  Year  Month  \
# ...

# %%
X = adidas_sales[['Units_Sold','Profit', 'Price_per_Unit']] #features
y = adidas_sales['Total_Sales'] # target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)
y_predicted
# Out:
# array([ 789.57129873,  621.39827292,  689.1025246 , ...,  696.13445332,
#        2222.18467472,  903.8667204 ])

# %%
model.score(X_test,y_test)
# Out:
# 0.667402503660887

# %% [markdown]
# ### 2. Random Forest

# %%
X = adidas_sales[['Units_Sold','Profit', 'Price_per_Unit']] #features
y = adidas_sales['Total_Sales'] # target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
model = RandomForestRegressor (n_estimators = 100)
model.fit(X_train, y_train)
y_predicted = model.predict(X_test)

# %%
model.score(X_test,y_test)
# Out:
# 0.9985838010597248

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 20846851.531443566

# %% [markdown]
# ### 3. Decision Tree

# %%
model = tree.DecisionTreeRegressor()
X = adidas_sales[['Units_Sold','Profit', 'Price_per_Unit']] #features
y = adidas_sales['Total_Sales'] # target
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

model.fit(X_train, y_train)
y_predicted = model.predict(X_test)

#Score
model.score(X_test,y_test)
# Out:
# 0.9972363768514642

# %%
# Evaluate the model
mse = mean_squared_error(y_test, y_pred)

print(f'Mean Squared Error: {mse}')
# Out:
# Mean Squared Error: 20846851.531443566

# %% [markdown]
# ### Conclusion

# %% [markdown]
# - Random Forest Model is performing best for this DataSet with accuracy score : 0.997
